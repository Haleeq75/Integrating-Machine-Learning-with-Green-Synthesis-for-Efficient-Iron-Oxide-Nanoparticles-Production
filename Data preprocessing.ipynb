# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
# Load dataset
df = pd.read_csv("Fe2O3.csv")

# %%
# Clean column names
df.columns = df.columns.str.replace('[^A-Za-z0-9_]+', '_', regex=True)

# %%
# Strip whitespaces
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# %%
# Define column categories
num_cols = ['extract_volume_mL_', 'conc_M_', 'precursor_volume_mL_', 'ph', 'time_hr_']
cat_cols = ['plant_extract', 'precursor', 'methods', 'additives']

# %%
# Fill missing numerical with mean
imputer_num = SimpleImputer(strategy='mean')
df[num_cols] = imputer_num.fit_transform(df[num_cols])

# %%
# Fill missing categorical with mode
imputer_cat = SimpleImputer(strategy='most_frequent')
df[cat_cols] = imputer_cat.fit_transform(df[cat_cols])

# %%
# Preview cleaned data
df.head()
# Out:
#                plant_extract  extract_volume_mL_ precursor  conc_M_  \
# 0        Syzygium aromaticum                15.0     FeCl3    0.001
# 1    Moringa oleifera leaves                20.0    Fe3Cl4    0.600
# 2      Madhuca indica leaves                90.0     FeSO4    0.025
# 3  Bauhinia tomentosa leaves                50.0     FeCl3    0.010
# 4             Jackfruit peel                30.0     FeCl2    0.100
#
#    precursor_volume_mL_   ph   time_hr_           methods  \
# 0                   5.0  6.0   1.000000  Co-Precipitation
# 1                  80.0  8.8   3.416667         waterbath
# 2                  10.0  8.8  24.000000  Co-Precipitation
# 3                  50.0  8.8   3.416667          Stirring
# 4                  20.0  6.0   3.416667  Co-Precipitation
#
#                      additives  particle_size_nm_
# 0                  0.10 M NaOH                 50
# 1                 60c sittirng                 16
# 2                 60c sittirng                 56
# 3  wash with water and acetone                 70
# 4                 60c sittirng                 32
